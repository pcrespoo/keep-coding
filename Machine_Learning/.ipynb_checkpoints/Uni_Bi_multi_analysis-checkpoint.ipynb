# %% [markdown]
# # Univariate, Bivariate and Multivariate Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Univariate Analysis

# %%
df_setosa = df[df.species=='setosa']

# %%
df_virginica = df[df.species=='virginica']

# %%
df_versicolor = df[df.species=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']))
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']))
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']))
plt.xlabel('Sepal Length')
# Out:
# Text(0.5, 0, 'Sepal Length')

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df,hue='species',size=5).map(plt.scatter,'petal_length','sepal_width').add_legend()

# %% [markdown]
# ### Multivariate Analysis
# - This plot shows us that petal_length and petal_width play an important role as they seem to be extremely correlated and making use of them may lead to
# an accurated model
# - The other scatter plots show us that we have neutral correlations and we can't draw any conclusion

# %%
sns.pairplot(df,hue='species',palette='rainbow')
